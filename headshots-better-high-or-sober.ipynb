# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('/kaggle/input/fortnite-statistics/Fortnite Statistics.csv')

data.head(2)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

sns.set_palette("dark")

sns.boxplot(x='Mental State', y='Head Shots', data=data, ax=axes[0])
axes[0].set_xlabel('Mental State')
axes[0].set_ylabel('Head Shots')
axes[0].set_title('Headshots by Mental State')

sns.violinplot(x='Mental State', y='Head Shots', data=data, ax=axes[1])
axes[1].set_xlabel('Mental State')
axes[1].set_ylabel('Head Shots')
axes[1].set_title('Headshots by Mental State')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Apparently, playing sober gets you to aim slightly better at enemy heads 🎯
